# %%
import re
import csv
import pandas as pd
import os
from camel_tools.utils import charsets
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.append('/Users/nurpeiis/Desktop/Capstone/hierarchical-did/utils')
from data_process import DataProcess

# %%
train_set = set()
test_set = set()
dev_set = set()
with open('../test.txt', 'r') as f:
    lines = f.read().splitlines()
    for line in lines:
        test_set.add(line)
with open('../train.txt', 'r') as f:
    lines = f.read().splitlines()
    for line in lines:
        train_set.add(line)
with open('../dev.txt', 'r') as f:
    lines = f.read().splitlines()
    for line in lines:
        dev_set.add(line)
# Out:
# {'CHT_ARZ_20120130.0000.transli.xml',
#  'CHT_ARZ_20120413.0001.transli.xml',
#  'CHT_ARZ_20120414.0001.transli.xml',
#  'CHT_ARZ_20120418.0001.transli.xml',
#  'CHT_ARZ_20120421.0003.transli.xml',
#  'CHT_ARZ_20120421.0004.transli.xml',
#  'CHT_ARZ_20120421.0005.transli.xml',
#  'CHT_ARZ_20120423.0000.transli.xml',
#  'CHT_ARZ_20120501.0002.transli.xml',
#  'CHT_ARZ_20120504.0001.transli.xml',
#  'CHT_ARZ_20120512.0002.transli.xml',
#  'CHT_ARZ_20120523.0002.transli.xml',
#  'CHT_ARZ_20120523.0003.transli.xml',
#  'CHT_ARZ_20120524.0001.transli.xml',
#  'CHT_ARZ_20120526.0001.transli.xml',
#  'CHT_ARZ_20120528.0001.transli.xml',
#  'CHT_ARZ_20120607.0001.transli.xml',
#  'CHT_ARZ_20120616.0003.transli.xml',
#  'CHT_ARZ_20120616.0004.transli.xml',
#  'CHT_ARZ_20120618.0001.transli.xml',
#  'CHT_ARZ_20120621.0002.transli.xml',
#  'CHT_ARZ_20120621.0003.transli.xml',
#  'CHT_ARZ_20120624.0000.transli.xml',
#  'CHT_ARZ_20120701.0002.transli.xml',
#  'CHT_ARZ_20120703.0002.transli.xml',
#  'CHT_ARZ_20120710.0002.transli.xml',
#  'CHT_ARZ_20120716.0001.transli.xml',
#  'CHT_ARZ_20120719.0003.transli.xml',
#  'CHT_ARZ_20120721.0001.transli.xml',
#  'CHT_ARZ_20120730.0001.transli.xml',
#  'CHT_ARZ_20120730.0002.transli.xml',
#  'CHT_ARZ_20120814.0002.transli.xml',
#  'CHT_ARZ_20120814.0003.transli.xml',
#  'CHT_ARZ_20120816.0003.transli.xml',
#  'CHT_ARZ_20120818.0006.transli.xml',
#  'CHT_ARZ_20120903.0001.transli.xml',
#  'CHT_ARZ_20120905.0001.transli.xml',
#  'CHT_ARZ_20120909.0004.transli.xml',
#  'CHT_ARZ_20120913.0001.transli.xml',
#  'CHT_ARZ_20121001.0001.transli.xml',
#  'CHT_ARZ_20121007.0003.transli.xml',
#  'CHT_ARZ_20121014.0004.transli.xml',
#  'CHT_ARZ_20121021.0005.transli.xml',
#  'CHT_ARZ_20121029.0001.transli.xml',
#  'CHT_ARZ_20121031.0000.transli.xml',
#  'CHT_ARZ_20121031.0001.transli.xml',
#  'CHT_ARZ_20121102.0001.transli.xml',
#  'CHT_ARZ_20121102.0003.transli.xml',
#  'CHT_ARZ_20121102.0005.transli.xml',
#  'CHT_ARZ_20121103.0000.transli.xml',
#  'CHT_ARZ_20121103.0002.transli.xml',
#  'CHT_ARZ_20121108.0000.transli.xml',
#  'CHT_ARZ_20121108.0002.transli.xml',
#  'CHT_ARZ_20121111.0002.transli.xml',
#  'CHT_ARZ_20121111.0003.transli.xml',
#  'CHT_ARZ_20121111.0004.transli.xml',
#  'CHT_ARZ_20121113.0000.transli.xml',
#  'CHT_ARZ_20121113.0001.transli.xml',
#  'CHT_ARZ_20121115.0000.transli.xml',
#  'CHT_ARZ_20121115.0002.transli.xml',
#  'CHT_ARZ_20121117.0001.transli.xml',
#  'CHT_ARZ_20121117.0002.transli.xml',
#  'CHT_ARZ_20121117.0004.transli.xml',
#  'CHT_ARZ_20121118.0000.transli.xml',
#  'CHT_ARZ_20121118.0005.transli.xml',
#  'CHT_ARZ_20121121.0000.transli.xml',
#  'CHT_ARZ_20121122.0000.transli.xml',
#  'CHT_ARZ_20121123.0000.transli.xml',
#  'CHT_ARZ_20121123.0001.transli.xml',
#  'CHT_ARZ_20121126.0001.transli.xml',
#  'CHT_ARZ_20121126.0002.transli.xml',
#  'CHT_ARZ_20121126.0003.transli.xml',
#  'CHT_ARZ_20121129.0000.transli.xml',
#  'CHT_ARZ_20121130.0000.transli.xml',
#  'CHT_ARZ_20121130.0002.transli.xml',
#  'CHT_ARZ_20121201.0000.transli.xml',
#  'CHT_ARZ_20121201.0002.transli.xml',
#  'CHT_ARZ_20121202.0002.transli.xml',
#  'CHT_ARZ_20121203.0001.transli.xml',
#  'CHT_ARZ_20121204.0000.transli.xml',
#  'CHT_ARZ_20121204.0009.transli.xml',
#  'CHT_ARZ_20121205.0001.transli.xml',
#  'CHT_ARZ_20121206.0000.transli.xml',
#  'CHT_ARZ_20121206.0003.transli.xml',
#  'CHT_ARZ_20121208.0000.transli.xml',
#  'CHT_ARZ_20121208.0001.transli.xml',
#  'CHT_ARZ_20121211.0002.transli.xml',
#  'CHT_ARZ_20121214.0000.transli.xml',
#  'CHT_ARZ_20121214.0001.transli.xml',
#  'CHT_ARZ_20121215.0001.transli.xml',
#  'CHT_ARZ_20121217.0000.transli.xml',
#  'CHT_ARZ_20121220.0001.transli.xml',
#  'CHT_ARZ_20121220.0002.transli.xml',
#  'CHT_ARZ_20121220.0003.transli.xml',
#  'CHT_ARZ_20121221.0001.transli.xml',
#  'CHT_ARZ_20121222.0000.transli.xml',
#  'CHT_ARZ_20121222.0002.transli.xml',
#  'CHT_ARZ_20121223.0000.transli.xml',
#  'CHT_ARZ_20121224.0000.transli.xml',
#  'CHT_ARZ_20121225.0000.transli.xml',
#  'CHT_ARZ_20121225.0001.transli.xml',
#  'CHT_ARZ_20121225.0003.transli.xml',
#  'CHT_ARZ_20121226.0000.transli.xml',
#  'CHT_ARZ_20121226.0001.transli.xml',
#  'CHT_ARZ_20121226.0003.transli.xml',
#  'SMS_ARZ_20110705.0000.transli.xml',
#  'SMS_ARZ_20110706.0002.transli.xml',
#  'SMS_ARZ_20110707.0000.transli.xml',
#  'SMS_ARZ_20110707.0001.transli.xml',
#  'SMS_ARZ_20110711.0000.transli.xml',
#  'SMS_ARZ_20110713.0000.transli.xml',
#  'SMS_ARZ_20110714.0001.transli.xml',
#  'SMS_ARZ_20110717.0001.transli.xml',
#  'SMS_ARZ_20110719.0000.transli.xml',
#  'SMS_ARZ_20110723.0001.transli.xml',
#  'SMS_ARZ_20110729.0000.transli.xml',
#  'SMS_ARZ_20110810.0001.transli.xml',
#  'SMS_ARZ_20110818.0001.transli.xml',
#  'SMS_ARZ_20110822.0000.transli.xml',
#  'SMS_ARZ_20110824.0000.transli.xml',
#  'SMS_ARZ_20110828.0000.transli.xml',
#  'SMS_ARZ_20110904.0001.transli.xml',
#  'SMS_ARZ_20110906.0000.transli.xml',
#  'SMS_ARZ_20110911.0001.transli.xml',
#  'SMS_ARZ_20110913.0000.transli.xml',
#  'SMS_ARZ_20110921.0000.transli.xml',
#  'SMS_ARZ_20110922.0000.transli.xml',
#  'SMS_ARZ_20110928.0000.transli.xml',
#  'SMS_ARZ_20110929.0000.transli.xml',
#  'SMS_ARZ_20111003.0001.transli.xml',
#  'SMS_ARZ_20111010.0000.transli.xml',
#  'SMS_ARZ_20111015.0000.transli.xml',
#  'SMS_ARZ_20111020.0000.transli.xml',
#  'SMS_ARZ_20111031.0000.transli.xml',
#  'SMS_ARZ_20111111.0000.transli.xml',
#  'SMS_ARZ_20111116.0001.transli.xml',
#  'SMS_ARZ_20111118.0001.transli.xml',
#  'SMS_ARZ_20111122.0001.transli.xml',
#  'SMS_ARZ_20111210.0000.transli.xml',
#  'SMS_ARZ_20111216.0001.transli.xml',
#  'SMS_ARZ_20111218.0000.transli.xml',
#  'SMS_ARZ_20111222.0000.transli.xml',
#  'SMS_ARZ_20120101.0000.transli.xml',
#  'SMS_ARZ_20120104.0001.transli.xml',
#  'SMS_ARZ_20120115.0000.transli.xml',
#  'SMS_ARZ_20120117.0000.transli.xml',
#  'SMS_ARZ_20120120.0000.transli.xml',
#  'SMS_ARZ_20120121.0000.transli.xml',
#  'SMS_ARZ_20120122.0000.transli.xml',
#  'SMS_ARZ_20120125.0000.transli.xml',
#  'SMS_ARZ_20120126.0002.transli.xml',
#  'SMS_ARZ_20120201.0000.transli.xml',
#  'SMS_ARZ_20120204.0000.transli.xml',
#  'SMS_ARZ_20120207.0000.transli.xml',
#  'SMS_ARZ_20120209.0000.transli.xml',
#  'SMS_ARZ_20120215.0000.transli.xml',
#  'SMS_ARZ_20120220.0000.transli.xml'}

# %%
import xml.etree.ElementTree as et 
#Step 0: From xml to csv
files = os.listdir('../../data_raw/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/data/transliteration')

cols = ["original_sentence"]
df_train = pd.DataFrame(columns=cols)
df_test = pd.DataFrame(columns=cols)
df_dev = pd.DataFrame(columns=cols)



for f in files:
    xtree = et.parse('../../data_raw/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/data/transliteration/' + f)
    xroot = xtree.getroot()
    rows = []
    for node in xroot:
        if node.find("corrected_transliteration") != None:
            rows.append({"original_sentence": node.find("corrected_transliteration").text})
    if f in train_set:
        df_train = df_train.append(rows, ignore_index=True)
    elif f in test_set:
        df_test = df_test.append(rows, ignore_index=True)
    elif f in dev_set:
        df_dev = df_dev.append(rows, ignore_index=True)



df_dev.to_csv('../../data_raw/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/dev_processed.tsv', sep='\t', index=False)
df_test.to_csv('../../data_raw/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/test_processed.tsv', sep='\t', index=False)
df_train.to_csv('../../data_raw/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/train_processed.tsv', sep='\t', index=False)

# %%
dp = DataProcess('../data_processed_splited/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/', 'user_level', 'sms', 'https://catalog.ldc.upenn.edu/LDC2017T07', 'ldc_bolt_sms_chat_ara_src_transliteration_2017_t07', {},{},0, 'corpus', 'original')

# %%
dp.save_file('dev_processed.tsv', dp.preprocess('../../data_raw/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/dev_processed.tsv', '', '', 'eg', 'nile_basin', header=0))
dp.save_file('test_processed.tsv', dp.preprocess('../../data_raw/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/test_processed.tsv', '', '', 'eg', 'nile_basin', header=0))
dp.save_file('train_processed.tsv', dp.preprocess('../../data_raw/ldc_bolt_sms_chat_ara_src_transliteration_2017_t07/train_processed.tsv', '', '', 'eg', 'nile_basin', header=0))

# %%
dp.save_features('../datasets_splited_features.tsv')
